# %% [markdown]
# ## Google Text to Speech API

# %%
pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.5.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\moan635\appdata\local\anaconda3\envs\py39\lib\site-packages (from gtts) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\moan635\appdata\local\anaconda3\envs\py39\lib\site-packages (from gtts) (8.1.7)
# Requirement already satisfied: colorama in c:\users\moan635\appdata\local\anaconda3\envs\py39\lib\site-packages (from click<8.2,>=7.1->gtts) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\moan635\appdata\local\anaconda3\envs\py39\lib\site-packages (from requests<3,>=2.27->gtts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\moan635\appdata\local\anaconda3\envs\py39\lib\site-packages (from requests<3,>=2.27->gtts) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\moan635\appdata\local\anaconda3\envs\py39\lib\site-packages (from requests<3,>=2.27->gtts) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\moan635\appdata\local\anaconda3\envs\py39\lib\site-packages (from requests<3,>=2.27->gtts) (2024.2.2)
# Downloading gTTS-2.5.1-py3-none-any.whl (29 kB)
# Installing collected packages: gtts
# Successfully installed gtts-2.5.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Imports

# %%
from gtts import gTTS
from IPython.display import Audio

# %% [markdown]
# ### Code

# %%
# read the txt file
with open('text.txt', "r") as text_file:
    transcription = text_file.read()

# %%
tts = gTTS(transcription, lang ="en" ,tld="com.br")
gtts_audio_file = 'text-gtts.mp3'
tts.save(gtts_audio_file)

# %%
Audio(gtts_audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
