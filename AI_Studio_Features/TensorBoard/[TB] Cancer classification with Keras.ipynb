# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard
from datetime import datetime
import os

# %%
os.environ
# Out:
# environ{'SHELL': '/bin/bash',
#         'NV_LIBCUBLAS_VERSION': '11.11.3.6-1',
#         'NVIDIA_VISIBLE_DEVICES': 'all',
#         'NV_CUDNN_PACKAGE_NAME': 'libcudnn8',
#         'NVIDIA_REQUIRE_CUDA': 'cuda>=11.8 brand=tesla,driver>=470,driver<471 brand=unknown,driver>=470,driver<471 brand=nvidia,driver>=470,driver<471 brand=nvidiartx,driver>=470,driver<471 brand=geforce,driver>=470,driver<471 brand=geforcertx,driver>=470,driver<471 brand=quadro,driver>=470,driver<471 brand=quadrortx,driver>=470,driver<471 brand=titan,driver>=470,driver<471 brand=titanrtx,driver>=470,driver<471',
#         'NV_NVTX_VERSION': '11.8.86-1',
#         'NV_LIBCUSPARSE_VERSION': '11.7.5.86-1',
#         'NV_LIBNPP_VERSION': '11.8.0.86-1',
#         'NCCL_VERSION': '2.15.5-1',
#         'JUPYTER_ALLOW_INSECURE_WRITES': 'true',
#         'PWD': '/home/jovyan',
#         'NV_CUDNN_PACKAGE': 'libcudnn8=8.9.6.50-1+cuda11.8',
#         'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility',
#         'NV_LIBNPP_PACKAGE': 'libnpp-11-8=11.8.0.86-1',
#         'NVIDIA_PRODUCT_NAME': 'CUDA',
#         'NV_CUDA_CUDART_VERSION': '11.8.89-1',
#         'HOME': '/home/jovyan',
#         'MLFLOW_TRACKING_URI': '/phoenix/mlflow',
#         'CUDA_VERSION': '11.8.0',
#         'NV_LIBCUBLAS_PACKAGE': 'libcublas-11-8=11.11.3.6-1',
#         'NV_LIBCUBLAS_PACKAGE_NAME': 'libcublas-11-8',
#         'HOST': '127.0.0.1',
#         'TENSORBOARD_LOGDIR': '/phoenix/tensorboard',
#         'NV_CUDNN_VERSION': '8.9.6.50',
#         'SHLVL': '0',
#         'NV_CUDA_LIB_VERSION': '11.8.0-1',
#         'NVARCH': 'x86_64',
#         'NV_CUDA_COMPAT_PACKAGE': 'cuda-compat-11-8',
#         'NV_LIBNCCL_PACKAGE': 'libnccl2=2.15.5-1+cuda11.8',
#         'LD_LIBRARY_PATH': '/usr/local/nvidia/lib:/usr/local/nvidia/lib64',
#         'JUPYTERLAB_INTERNAL_PORT': '8889',
#         'JUPYTERLAB_PORT': '8888',
#         'PATH': '/opt/node-v18.17.0-linux-x64/bin:/opt/conda/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin',
#         'NV_LIBNCCL_PACKAGE_NAME': 'libnccl2',
#         'NV_LIBNCCL_PACKAGE_VERSION': '2.15.5-1',
#         '_': '/opt/conda/bin/jupyter',
#         'LC_CTYPE': 'C.UTF-8',
#         'GIT_PYTHON_REFRESH': 'quiet',
#         'JPY_SESSION_NAME': '/home/jovyan/datafabric/reorg-main/AI_Studio_Features/TensorBoard/[TB] Cancer classification with Keras.ipynb',
#         'JPY_PARENT_PID': '1',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline',
#         'KMP_DUPLICATE_LIB_OK': 'True',
#         'KMP_INIT_AT_FORK': 'FALSE',
#         'TPU_ML_PLATFORM': 'Tensorflow',
#         'TF2_BEHAVIOR': '1'}

# %%
df = pd.read_csv('/mnt/c/Users/ViDi132/Desktop/data-repositry/cancer_classification.csv')

# %%
X = df.drop('benign_0__mal_1',axis=1).values
y = df['benign_0__mal_1'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=101)

# %% [markdown]
# ### Scaling Data

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Creating the Model

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
datetime.now().strftime("%Y-%m-%d--%H%M")
# Out:
# '2024-04-24--2020'

# %%
board = TensorBoard(log_dir="/phoenix/tensorboard/tensorlogs", histogram_freq=1,
    write_graph=True,
    write_images=True,
    update_freq='epoch',
    profile_batch=2,
    embeddings_freq=1)
# Out:
# 2024-04-24 20:32:42.478315: I tensorflow/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2024-04-24 20:32:42.478390: I tensorflow/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2024-04-24 20:32:42.478451: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:135] cuptiGetTimestamp: ignored due to a previous error.
# 2024-04-24 20:32:42.478465: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:186] cuptiSubscribe: ignored due to a previous error.
# 2024-04-24 20:32:42.478472: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:459] cuptiGetResultString: ignored due to a previous error.
# 2024-04-24 20:32:42.478480: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_tracer.cc:1723] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error
# 2024-04-24 20:32:42.479199: I tensorflow/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2024-04-24 20:32:42.485781: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:142] cuptiFinalize: ignored due to a previous error.
# 2024-04-24 20:32:42.485827: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:459] cuptiGetResultString: ignored due to a previous error.
# 2024-04-24 20:32:42.485835: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_tracer.cc:1814] function cupti_interface_->Finalize()failed with error

# %% [markdown]
# Now create the model layers:

# %%
model = Sequential()
model.add(Dense(units=30,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=15,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')

# %% [markdown]
# ## Train the Model

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=600,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop,board]
          )
# Out:
# Epoch 1/600
# 11/14 [======================>.......] - ETA: 0s - loss: 0.6746
# 2024-04-24 20:32:48.341560: I tensorflow/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2024-04-24 20:32:48.341673: I tensorflow/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2024-04-24 20:32:48.341728: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:135] cuptiGetTimestamp: ignored due to a previous error.
# 2024-04-24 20:32:48.341747: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:186] cuptiSubscribe: ignored due to a previous error.
# 2024-04-24 20:32:48.341757: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:459] cuptiGetResultString: ignored due to a previous error.
# 2024-04-24 20:32:48.341765: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_tracer.cc:1723] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error
# 2024-04-24 20:32:48.391561: I tensorflow/tsl/profiler/lib/profiler_session.cc:70] Profiler session collecting data.
# 2024-04-24 20:32:48.399404: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:142] cuptiFinalize: ignored due to a previous error.
# 2024-04-24 20:32:48.399537: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:459] cuptiGetResultString: ignored due to a previous error.
# 2024-04-24 20:32:48.399552: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_tracer.cc:1814] function cupti_interface_->Finalize()failed with error
# 2024-04-24 20:32:48.403962: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:135] cuptiGetTimestamp: ignored due to a previous error.
# 2024-04-24 20:32:48.404053: E tensorflow/compiler/xla/backends/profiler/gpu/cupti_error_manager.cc:135] cuptiGetTimestamp: ignored due to a previous error.
# 2024-04-24 20:32:48.404071: I tensorflow/compiler/xla/backends/profiler/gpu/cupti_collector.cc:541]  GpuTracer has collected 0 callback api events and 0 activity events.
# 2024-04-24 20:32:48.404346: I tensorflow/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2024-04-24 20:32:48.415843: I tensorflow/tsl/profiler/rpc/client/save_profile.cc:144] Collecting XSpace to repository: /phoenix/tensorboard/tensorlogs/plugins/profile/2024_04_24_20_32_48/HP-CND1354WKQ.xplane.pb
# 14/14 [==============================] - 2s 54ms/step - loss: 0.6754 - val_loss: 0.6508
# Epoch 2/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.6676 - val_loss: 0.6317
# Epoch 3/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.6363 - val_loss: 0.6147
# Epoch 4/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.6163 - val_loss: 0.5938
# Epoch 5/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.6165 - val_loss: 0.5786
# Epoch 6/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.5923 - val_loss: 0.5626
# Epoch 7/600
# 14/14 [==============================] - 0s 31ms/step - loss: 0.5753 - val_loss: 0.5418
# Epoch 8/600
# 14/14 [==============================] - 0s 27ms/step - loss: 0.5513 - val_loss: 0.5243
# Epoch 9/600
# 14/14 [==============================] - 0s 29ms/step - loss: 0.5370 - val_loss: 0.5027
# Epoch 10/600
# 14/14 [==============================] - 0s 26ms/step - loss: 0.5205 - val_loss: 0.4855
# Epoch 11/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.5062 - val_loss: 0.4637
# Epoch 12/600
# 14/14 [==============================] - 0s 28ms/step - loss: 0.4881 - val_loss: 0.4404
# Epoch 13/600
# 14/14 [==============================] - 0s 30ms/step - loss: 0.4842 - val_loss: 0.4222
# Epoch 14/600
# 14/14 [==============================] - 0s 31ms/step - loss: 0.4552 - val_loss: 0.3967
# Epoch 15/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.4252 - val_loss: 0.3713
# Epoch 16/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.4383 - val_loss: 0.3568
# Epoch 17/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.4278 - val_loss: 0.3457
# Epoch 18/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.3985 - val_loss: 0.3204
# Epoch 19/600
# 14/14 [==============================] - 0s 37ms/step - loss: 0.4000 - val_loss: 0.3125
# Epoch 20/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.3917 - val_loss: 0.2977
# Epoch 21/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.3857 - val_loss: 0.2867
# Epoch 22/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.3602 - val_loss: 0.2793
# Epoch 23/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.3473 - val_loss: 0.2667
# Epoch 24/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.3378 - val_loss: 0.2539
# Epoch 25/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.3583 - val_loss: 0.2534
# Epoch 26/600
# 14/14 [==============================] - 0s 37ms/step - loss: 0.3322 - val_loss: 0.2382
# Epoch 27/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.3175 - val_loss: 0.2341
# Epoch 28/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.3225 - val_loss: 0.2293
# Epoch 29/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.3061 - val_loss: 0.2206
# Epoch 30/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.2991 - val_loss: 0.2080
# Epoch 31/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.2896 - val_loss: 0.2026
# Epoch 32/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.2827 - val_loss: 0.1939
# Epoch 33/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.2711 - val_loss: 0.1870
# Epoch 34/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.2611 - val_loss: 0.1831
# Epoch 35/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.2631 - val_loss: 0.1724
# Epoch 36/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.2500 - val_loss: 0.1709
# Epoch 37/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.2375 - val_loss: 0.1689
# Epoch 38/600
# 14/14 [==============================] - 1s 43ms/step - loss: 0.2586 - val_loss: 0.1814
# Epoch 39/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.2419 - val_loss: 0.1602
# Epoch 40/600
# 14/14 [==============================] - 1s 44ms/step - loss: 0.2366 - val_loss: 0.1543
# Epoch 41/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.2417 - val_loss: 0.1604
# Epoch 42/600
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2258 - val_loss: 0.1520
# Epoch 43/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.2485 - val_loss: 0.1501
# Epoch 44/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.2200 - val_loss: 0.1460
# Epoch 45/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.2439 - val_loss: 0.1470
# Epoch 46/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.2223 - val_loss: 0.1404
# Epoch 47/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.2230 - val_loss: 0.1475
# Epoch 48/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.2081 - val_loss: 0.1405
# Epoch 49/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1947 - val_loss: 0.1420
# Epoch 50/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.2158 - val_loss: 0.1378
# Epoch 51/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.1792 - val_loss: 0.1374
# Epoch 52/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1801 - val_loss: 0.1304
# Epoch 53/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.2118 - val_loss: 0.1324
# Epoch 54/600
# 14/14 [==============================] - 0s 31ms/step - loss: 0.1908 - val_loss: 0.1304
# Epoch 55/600
# 14/14 [==============================] - 0s 28ms/step - loss: 0.1593 - val_loss: 0.1312
# Epoch 56/600
# 14/14 [==============================] - 0s 27ms/step - loss: 0.1870 - val_loss: 0.1337
# Epoch 57/600
# 14/14 [==============================] - 0s 27ms/step - loss: 0.1674 - val_loss: 0.1278
# Epoch 58/600
# 14/14 [==============================] - 0s 27ms/step - loss: 0.1857 - val_loss: 0.1212
# Epoch 59/600
# 14/14 [==============================] - 0s 28ms/step - loss: 0.1681 - val_loss: 0.1236
# Epoch 60/600
# 14/14 [==============================] - 0s 27ms/step - loss: 0.1829 - val_loss: 0.1242
# Epoch 61/600
# 14/14 [==============================] - 0s 30ms/step - loss: 0.1727 - val_loss: 0.1287
# Epoch 62/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1785 - val_loss: 0.1290
# Epoch 63/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1777 - val_loss: 0.1253
# Epoch 64/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1507 - val_loss: 0.1254
# Epoch 65/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.1695 - val_loss: 0.1209
# Epoch 66/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1695 - val_loss: 0.1197
# Epoch 67/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.1786 - val_loss: 0.1308
# Epoch 68/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1799 - val_loss: 0.1219
# Epoch 69/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1423 - val_loss: 0.1172
# Epoch 70/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1414 - val_loss: 0.1195
# Epoch 71/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1418 - val_loss: 0.1243
# Epoch 72/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1417 - val_loss: 0.1173
# Epoch 73/600
# 14/14 [==============================] - 0s 37ms/step - loss: 0.1521 - val_loss: 0.1196
# Epoch 74/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.1313 - val_loss: 0.1137
# Epoch 75/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.1537 - val_loss: 0.1178
# Epoch 76/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1574 - val_loss: 0.1214
# Epoch 77/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1537 - val_loss: 0.1195
# Epoch 78/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1253 - val_loss: 0.1202
# Epoch 79/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.1543 - val_loss: 0.1170
# Epoch 80/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1614 - val_loss: 0.1168
# Epoch 81/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1362 - val_loss: 0.1144
# Epoch 82/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.1329 - val_loss: 0.1264
# Epoch 83/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1680 - val_loss: 0.1170
# Epoch 84/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1478 - val_loss: 0.1134
# Epoch 85/600
# 14/14 [==============================] - 1s 41ms/step - loss: 0.1164 - val_loss: 0.1211
# Epoch 86/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1482 - val_loss: 0.1093
# Epoch 87/600
# 14/14 [==============================] - 1s 38ms/step - loss: 0.1169 - val_loss: 0.1169
# Epoch 88/600
# 14/14 [==============================] - 0s 37ms/step - loss: 0.1378 - val_loss: 0.1219
# Epoch 89/600
# 14/14 [==============================] - 1s 42ms/step - loss: 0.1654 - val_loss: 0.1137
# Epoch 90/600
# 14/14 [==============================] - 1s 40ms/step - loss: 0.1420 - val_loss: 0.1129
# Epoch 91/600
# 14/14 [==============================] - 1s 38ms/step - loss: 0.1435 - val_loss: 0.1201
# Epoch 92/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.1234 - val_loss: 0.1181
# Epoch 93/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.1213 - val_loss: 0.1100
# Epoch 94/600
# 14/14 [==============================] - 0s 30ms/step - loss: 0.1326 - val_loss: 0.1181
# Epoch 95/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.1292 - val_loss: 0.1152
# Epoch 96/600
# 14/14 [==============================] - 1s 38ms/step - loss: 0.1273 - val_loss: 0.1131
# Epoch 97/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1368 - val_loss: 0.1075
# Epoch 98/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1185 - val_loss: 0.1138
# Epoch 99/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1243 - val_loss: 0.1131
# Epoch 100/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1203 - val_loss: 0.1224
# Epoch 101/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.1331 - val_loss: 0.1283
# Epoch 102/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1232 - val_loss: 0.1136
# Epoch 103/600
# 14/14 [==============================] - 0s 30ms/step - loss: 0.1254 - val_loss: 0.1146
# Epoch 104/600
# 14/14 [==============================] - 0s 28ms/step - loss: 0.1051 - val_loss: 0.1169
# Epoch 105/600
# 14/14 [==============================] - 0s 30ms/step - loss: 0.1201 - val_loss: 0.1184
# Epoch 106/600
# 14/14 [==============================] - 0s 30ms/step - loss: 0.1090 - val_loss: 0.1165
# Epoch 107/600
# 14/14 [==============================] - 0s 29ms/step - loss: 0.1188 - val_loss: 0.1134
# Epoch 108/600
# 14/14 [==============================] - 0s 30ms/step - loss: 0.1052 - val_loss: 0.1210
# Epoch 109/600
# 14/14 [==============================] - 0s 30ms/step - loss: 0.1001 - val_loss: 0.1238
# Epoch 110/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.1265 - val_loss: 0.1132
# Epoch 111/600
# 14/14 [==============================] - 1s 47ms/step - loss: 0.1228 - val_loss: 0.1223
# Epoch 112/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.1237 - val_loss: 0.1200
# Epoch 113/600
# 14/14 [==============================] - 1s 51ms/step - loss: 0.1177 - val_loss: 0.1142
# Epoch 114/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0912 - val_loss: 0.1172
# Epoch 115/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1185 - val_loss: 0.1208
# Epoch 116/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1150 - val_loss: 0.1135
# Epoch 117/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.1042 - val_loss: 0.1151
# Epoch 118/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1182 - val_loss: 0.1178
# Epoch 119/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1112 - val_loss: 0.1172
# Epoch 120/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.1255 - val_loss: 0.1230
# Epoch 121/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.1168 - val_loss: 0.1243
# Epoch 122/600
# 14/14 [==============================] - 1s 41ms/step - loss: 0.1102 - val_loss: 0.1133
# Epoch 122: early stopping
